# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# ## **(1) pi estimate**

# %%
N=1000
fig, ax = plt.subplots()
points = np.random.uniform(0, 1, size=(N,2))
ax.scatter(points[:,0],points[:,1],s=.5)
circle1 = plt.Circle((0, 0), 1, color='r', alpha=.5)
ax.add_patch(circle1)
ax.set_aspect('equal')
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %%
#pi estimation
#count num inside, which is num with x^2+y^2<1

valid = 0
for i in range(len(points)):
    x = points[i,0]
    y = points[i,1]
    # print(f'{x},{y}')
    if x**2+y**2 < 1:
        valid+=1
print(f'valid points/1000: {valid}')

# pi estimate logic: quarter circle has area pi/4, so multiply valid/1000 by 4
pi_estimate = valid*4/1000
print(f'pi estimate:{pi_estimate}')
# Out:
# valid points/1000: 774
# pi estimate:3.096

# %%
#try again w/ N=1e4, 1e6
#np.where on massive array is quite slow. is there a better way to do this?
def pi_estimate_N(N):
    print(f'estimate pi for sample N={N}')
    fig, ax = plt.subplots()
    points = np.random.uniform(0, 1, size=(N,2))
    x = points[:,0]
    y = points[:,1]
    color = np.where(x**2+y**2>1, 'blue', 'red')
    ax.scatter(x,y,s=.5,color=color)
    circle1 = plt.Circle((0, 0), 1, fill=False,edgecolor='black', alpha=1)
    ax.add_patch(circle1)
    ax.set_aspect('equal')
    plt.xlim(0,1)
    plt.ylim(0,1)
    plt.show()

    valid = 0
    for i in range(N):
        if x[i]**2+y[i]**2 < 1:
            valid+=1
    print(f'valid points/{N}: {valid}')

    pi_estimate = valid*4/N
    print(f'pi estimate:{pi_estimate}')
    print('____')

pi_estimate_N(int(1e4))
pi_estimate_N(int(1e6))
# Out:
# estimate pi for sample N=10000
# valid points/10000: 7844
# pi estimate:3.1376
# ____
# estimate pi for sample N=1000000
# valid points/1000000: 785563
# pi estimate:3.142252
# ____

# %% [markdown]
# estimate's already pretty close for N=1000 and gets significantly closer as we crank N up.
